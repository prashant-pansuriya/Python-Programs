# %%
# write Programe
# (1)^2*((1)^2+(2)^2))*((1)^2+(2)^2)+(3)^2)......n
#here enter n value

print('please enter your sum of number')
a=int(input())
ml=1
for i in range(1,a+1):
  sum=0
  for j in range(1,i+1):
    
    j=j**2
    sum=sum+j
  ml=ml*sum
print(ml)
# Out:
# please enter your sum of number
# 2
# 5
